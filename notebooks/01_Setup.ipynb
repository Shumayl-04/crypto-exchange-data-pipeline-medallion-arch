# %% [markdown]
# # Setup

# %% [markdown]
# # Configure Access to Cloud Storage via Unity Catalog

# %% [markdown]
# Access Cloud Storage

# %%
# %sql
SELECT current_metastore()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_metastore()</th></tr></thead><tbody><tr><td>azure:westus:58940824-f549-457d-a41f-290d3af56c25</td></tr></tbody></table></div>

# %%
# %fs ls 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/raw/</td><td>raw/</td><td>0</td><td>1786393342000</td></tr></tbody></table></div>

# %% [markdown]
# ### Create External Location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS cryptoexchangedata_crypto_exchange_container
    URL 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/' 
    WITH (STORAGE CREDENTIAL crypto_exchange_ext_sc)
    COMMENT 'External location for crypto exchange data'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Create Catalog - ecommerce

# %%
# %sql
SHOW CATALOGS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>__databricks_internal</td></tr><tr><td>db_crypt_exchange_ws</td></tr><tr><td>ecommerce</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr></tbody></table></div>

# %%
# %sql
CREATE CATALOG IF NOT EXISTS crypto_exchange
    MANAGED LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/'
    COMMENT 'Catalog for crypto exchange data';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# %md
# ### Create Schema
# 1. landing
# 2. Bronze
# 3. Silver
# 4. Gold

# %%
# %sql
SELECT current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>db_crypt_exchange_ws</td></tr></tbody></table></div>

# %%
# %sql
USE CATALOG crypto_exchange;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS landing
    MANAGED LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/landing';

CREATE SCHEMA IF NOT EXISTS bronze
    MANAGED LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS silver
    MANAGED LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS gold
    MANAGED LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/gold';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>bronze</td></tr><tr><td>default</td></tr><tr><td>gold</td></tr><tr><td>information_schema</td></tr><tr><td>landing</td></tr><tr><td>silver</td></tr></tbody></table></div>

# %% [markdown]
# %md
# ## Create Volume

# %%
# %sql
USE CATALOG crypto_exchange;
USE SCHEMA landing;

CREATE EXTERNAL VOLUME IF NOT EXISTS cryptoexchange_data
    LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/landing/data';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls /Volumes/crypto_exchange/landing/cryptoexchange_data
# Out:
# []

# %% [markdown]
# ### Create meta data colume for schema and checkpoints

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS crypto_exchange.landing.autoloader_meta
    LOCATION 'abfss://crypto-exchange-container@cryptoexchangedata.dfs.core.windows.net/landing/autoloader_meta';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
